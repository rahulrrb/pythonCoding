# %% [markdown]
# You are given a string and your task is to swap cases. In other words, **convert all lowercase letters to uppercase letters and vice versa.**
#
# Ex-
# * Www.HackerRank.com → wWW.hACKERrANK.COM
# * Pythonist 2 → pYTHONIST 2

# %%
def swap_case_with_digit(s):
    result = ""
    for char in s:
        if char.isupper():
            result += char.lower()
        elif char.islower():
            result += char.upper()
        else:
            result += char
    return result

if __name__ == '__main__':
    s = input()
    result = swap_case_with_digit(s)
    print(result)
# Out:
#  Www.HackerRank.com
